# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# %%
#Checking working directory
os.getcwd()
# Out:
# 'D:\\Learning\\USF - Data Science Programming\\Assignment 1'

# %%
#Loading the csv file onto a pandas dataframe
df = pd.read_csv("dengue_features_train.csv")

# %%
#Displaying the top 3 rows of data for better understanding
df.head(3)
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.12260  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.16990  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.03225  0.172967  0.157200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# 1                            17.94                             77.368571
# 2                            26.10                             82.052857
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
#Creating a copy of the original data-frame to avoid making changes to the original
df_rn = df.copy()

# %%
#Calling the str.replace function to replace all column names containing 'station' with 'stn'
df_rn.columns = df_rn.columns.str.replace('station', 'stn')

# %%
#Calling the head to look at the data and verify if the string replacement has been done properly
df_rn.head(3)
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.12260  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.16990  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.03225  0.172967  0.157200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# 1                            17.94                             77.368571
# 2                            26.10                             82.052857
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# ...

# %%
df_rn.columns = df_rn.columns.str.replace('precip', 'prec')
df_rn.columns = df_rn.columns.str.replace('humidity', 'hd')
df_rn.columns = df_rn.columns.str.replace('reanalysis', 're_an')

#Listing out column names to check if the replacements have been effected. Not using head() as some column names are hidden from view
#Using the info() function to combine the answers for questions 1)e) and 1)f)
df_rn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        1456 non-null   object
#  1   year                        1456 non-null   int64
#  2   weekofyear                  1456 non-null   int64
#  3   week_start_date             1456 non-null   object
#  4   ndvi_ne                     1262 non-null   float64
#  5   ndvi_nw                     1404 non-null   float64
#  6   ndvi_se                     1434 non-null   float64
#  7   ndvi_sw                     1434 non-null   float64
#  8   prec_amt_mm                 1443 non-null   float64
#  9   re_an_air_temp_k            1446 non-null   float64
#  10  re_an_avg_temp_k            1446 non-null   float64
#  11  re_an_dew_point_temp_k      1446 non-null   float64
#  12  re_an_max_air_temp_k        1446 non-null   float64
# ...

# %%
#Converting the column 'Year' to category and verifying the same~
df_rn.year = df_rn.year.astype('category')
df_rn.dtypes
# Out:
# city                            object
# year                          category
# weekofyear                       int64
# week_start_date                 object
# ndvi_ne                        float64
# ndvi_nw                        float64
# ndvi_se                        float64
# ndvi_sw                        float64
# prec_amt_mm                    float64
# re_an_air_temp_k               float64
# re_an_avg_temp_k               float64
# re_an_dew_point_temp_k         float64
# re_an_max_air_temp_k           float64
# re_an_min_air_temp_k           float64
# re_an_prec_amt_kg_per_m2       float64
# re_an_relative_hd_percent      float64
# re_an_sat_prec_amt_mm          float64
# re_an_specific_hd_g_per_kg     float64
# re_an_tdtr_k                   float64
# stn_avg_temp_c                 float64
# stn_diur_temp_rng_c            float64
# stn_max_temp_c                 float64
# stn_min_temp_c                 float64
# stn_prec_mm                    float64
# dtype: object

# %%
df_pred = pd.read_csv("dengue_labels_train.csv")
df_pred.head(3)
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4

# %%
df_merged = pd.merge(df_rn, df_pred, on=['city','year','weekofyear'], how='outer')

# %%
df_merged
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1      sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2      sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3      sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4      sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# ...   ...   ...         ...             ...       ...       ...       ...
# 1451   iq  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_relative_hd_percent  \
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        1456 non-null   object
#  1   year                        1456 non-null   int64
#  2   weekofyear                  1456 non-null   int64
#  3   week_start_date             1456 non-null   object
#  4   ndvi_ne                     1262 non-null   float64
#  5   ndvi_nw                     1404 non-null   float64
#  6   ndvi_se                     1434 non-null   float64
#  7   ndvi_sw                     1434 non-null   float64
#  8   prec_amt_mm                 1443 non-null   float64
#  9   re_an_air_temp_k            1446 non-null   float64
#  10  re_an_avg_temp_k            1446 non-null   float64
#  11  re_an_dew_point_temp_k      1446 non-null   float64
#  12  re_an_max_air_temp_k        1446 non-null   float64
# ...

# %%
#Counting the no. of NaN values in the dataframe
df_merged.isna().sum()
# Out:
# city                            0
# year                            0
# weekofyear                      0
# week_start_date                 0
# ndvi_ne                       194
# ndvi_nw                        52
# ndvi_se                        22
# ndvi_sw                        22
# prec_amt_mm                    13
# re_an_air_temp_k               10
# re_an_avg_temp_k               10
# re_an_dew_point_temp_k         10
# re_an_max_air_temp_k           10
# re_an_min_air_temp_k           10
# re_an_prec_amt_kg_per_m2       10
# re_an_relative_hd_percent      10
# re_an_sat_prec_amt_mm          13
# re_an_specific_hd_g_per_kg     10
# re_an_tdtr_k                   10
# stn_avg_temp_c                 43
# stn_diur_temp_rng_c            43
# stn_max_temp_c                 20
# stn_min_temp_c                 14
# stn_prec_mm                    22
# total_cases                     0
# dtype: int64

# %%
#Using forward fill to fill the NaNs 
df_merged = df_merged.fillna(method='ffill')

# %%
#Checking to see if all NaNs have been filled
df_merged.isna().sum()
# Out:
# city                          0
# year                          0
# weekofyear                    0
# week_start_date               0
# ndvi_ne                       0
# ndvi_nw                       0
# ndvi_se                       0
# ndvi_sw                       0
# prec_amt_mm                   0
# re_an_air_temp_k              0
# re_an_avg_temp_k              0
# re_an_dew_point_temp_k        0
# re_an_max_air_temp_k          0
# re_an_min_air_temp_k          0
# re_an_prec_amt_kg_per_m2      0
# re_an_relative_hd_percent     0
# re_an_sat_prec_amt_mm         0
# re_an_specific_hd_g_per_kg    0
# re_an_tdtr_k                  0
# stn_avg_temp_c                0
# stn_diur_temp_rng_c           0
# stn_max_temp_c                0
# stn_min_temp_c                0
# stn_prec_mm                   0
# total_cases                   0
# dtype: int64

# %%
#Checking if all the values are same even after merging
df_pred[:3]
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4

# %%
df_rn[:3]
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.12260  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.16990  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.03225  0.172967  0.157200
#
#     ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_prec_amt_kg_per_m2  \
# 0  0.177617        12.42        297.572857  ...                     32.00
# 1  0.155486        22.82        298.211429  ...                     17.94
# 2  0.170843        34.54        298.781429  ...                     26.10
#
#    re_an_relative_hd_percent  re_an_sat_prec_amt_mm  \
# 0                  73.365714                  12.42
# 1                  77.368571                  22.82
# 2                  82.052857                  34.54
#
#    re_an_specific_hd_g_per_kg  re_an_tdtr_k  stn_avg_temp_c  \
# 0                   14.012857      2.628571       25.442857
# ...

# %%
df_merged[:3]
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.12260  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.16990  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.03225  0.172967  0.157200
#
#     ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_relative_hd_percent  \
# 0  0.177617        12.42        297.572857  ...                  73.365714
# 1  0.155486        22.82        298.211429  ...                  77.368571
# 2  0.170843        34.54        298.781429  ...                  82.052857
#
#    re_an_sat_prec_amt_mm  re_an_specific_hd_g_per_kg  re_an_tdtr_k  \
# 0                  12.42                   14.012857      2.628571
# 1                  22.82                   15.372857      2.371429
# 2                  34.54                   16.848571      2.300000
#
#    stn_avg_temp_c  stn_diur_temp_rng_c  stn_max_temp_c  stn_min_temp_c  \
# ...

# %%
#Scatterplot of 'weekofyear' vs. 'totalcases'
scat1 = df_merged.plot.scatter(x='weekofyear',
                              y='total_cases',
                              title='Relationship between Total Cases & Weeks of the Year')
scat1.set_xlabel("Weeks of the Year")
scat1.set_ylabel("Total Cases")
plt.show()

# From the scatterplot seen below, it looks like there is a weak positive relationship between the total cases and 
# weeks of the year with. The count of cases increases for certain years between the 30th and 50th weeks

# %%
df_boxp = df_merged.sample(n=110, random_state=786)

box1 = df_boxp.boxplot(column='total_cases', by='city', vert=False, figsize=(15,5))
box1.set_xlabel("Total Cases")
box1.set_ylabel("City")
plt.title("Total Cases grouped by City for a sample of 110 records")
plt.suptitle("")

box2 = df_merged.boxplot(column='total_cases', by='city', vert=False, figsize=(15,5))
box2.set_xlabel("Total Cases")
box1.set_ylabel("City")
plt.title("Total Cases grouped by City for entire dataframe")
plt.suptitle("") 

# As we can see below, for a large enough sample the mean of the sample seems to represent the mean of the 
# population.
# Out:
# Text(0.5, 0.98, '')

# %%
df_grouped = df_merged.groupby('city')['total_cases']
#Mean of total_cases by city
print('Mean of total cases by city', '\n', df_grouped.mean(),'\n')

#Min of total_cases by city
print('Minimum of total cases by city', '\n', df_grouped.min(), '\n')
print('Maximum of total cases by city', '\n', df_grouped.max(), '\n')
print('Standard deviation of total cases by city', '\n', df_grouped.std(), '\n')
# Out:
# Mean of total cases by city
#  city
# iq     7.565385
# sj    34.180556
# Name: total_cases, dtype: float64
#
# Minimum of total cases by city
#  city
# iq    0
# sj    0
# Name: total_cases, dtype: int64
#
# Maximum of total cases by city
#  city
# iq    116
# sj    461
# Name: total_cases, dtype: int64
#
# Standard deviation of total cases by city
#  city
# iq    10.765478
# sj    51.381372
# Name: total_cases, dtype: float64

# %%
hist1 = df_merged.hist(column = 'total_cases', by = 'city', figsize=(15,5), bins=10)
plt.xlabel('Total Cases')
plt.ylabel('Frequency')
plt.title('Histogram of Total Cases by City')

# As we can see here, the majority of the data is within two standard deviations of the mean and the rest of the 
# data is contained in one of the tails
# Out:
# Text(0.5, 1.0, 'Histogram of Total Cases by City')

# %%
df_iq = df_merged[df_merged['city'] == 'iq']

# %%
df_iq.pivot_table(index = ["year"], values = ["total_cases"], aggfunc=np.sum)

# There are 9 years with a total of more than or equal to 50 Dengue cases. The years are 2002, 2003, 2004, 2005,
# 2006, 2007, 2008, 2009 and 2010
# Out:
#       total_cases
# year
# 2000            4
# 2001           14
# 2002          704
# 2003          114
# 2004          638
# 2005          311
# 2006          436
# 2007          365
# 2008          801
# 2009          324
# 2010          223

# %%
df_temp = df_merged.groupby('weekofyear')['total_cases']
df_temp

# %%
df_temp.plot(kind = 'hist', legend = True, figsize=(20,20))
plt.xlabel('Total Cases by Week')
plt.ylabel('Frequency')
plt.title('Histogram of Total Cases by Weeks of the Year')
plt.show()

# Based on the histogram, I can see that the data for most of the weeks is skewed to the right
